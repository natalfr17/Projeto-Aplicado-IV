# %% [markdown]
# <a href="https://colab.research.google.com/github/natalfr17/Projeto-Aplicado-IV/blob/main/cd_projeto_aplicado_IV_entrega_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
#   <img src="https://raw.githubusercontent.com/scalabrinig/cdProjetoAplicadoIV/d093146488f56dfcf0ef286bcee8efe0e71b9c76/figuras/mackenzie_logo.jpg" width="25%" align="right"/>
#
# # **PROJETO APLICADO IV - Ciência de Dados EaD - 2025/01**
#
#
# # **Entrega 3**
#
# ---

# %% [markdown]
# # **Título do Projeto**
# ---

# %%
#@title **Identificação do Grupo e Opção do Projeto**

#@markdown Integrantes do Grupo, nome completo em ordem alfabética (*informe: \<nome\>, \<matrícula\>*)
#@markdown Integrantes do Grupo, nome completo em ordem alfabética (*informe: \, \*)
Aluno1 = 'ADRIANO MAMORU TAKESHITA, 10415887' #@param {type:"string"}
Aluno2 = 'ISAQUE SANTA BRIGIDA PIMENTEL , 10415608' #@param {type:"string"}
Aluno3 = 'NATALIA FRANÇOZO , 10415636' #@param {type:"string"}
Aluno4 = 'VITOR DOMINGOS BALDOINO DOS SANTOS , 10414498' #@param {type:"string"}

# %% [markdown]
# # **Introdução**
#
# A qualidade da educação é um dos Objetivos de Desenvolvimento Sustentável (ODS) da Organização das Nações Unidas (ONU), especificamente o tema 4, que visa assegurar a educação inclusiva, equitativa e de qualidade, promovendo oportunidades de aprendizagem ao longo da vida para todos. Este projeto de insere-se no contexto da análise da taxa de conclusão no ensino superior.
#
# Será desenvolvido um modelo de séries temporais com o intuito de analisar o comportamento dos alunos matriculados no ensino superior, verificando o percentual de alunos que concluem e o percentual que não conclui o curso ao longo dos anos analisados. O problema selecionado aborda a identificação das principais causas que influenciam a não conclusão dos cursos e a predição da probabilidade de alunos com determinadas características não concluírem o ensino superior.
#
# O estudo da taxa de conclusão no ensino superior mostra sua relevância ao buscar identificar e entender os fatores que influenciam a evasão acadêmica. A partir dessa compreensão, é possível desenvolver políticas e estratégias que promovam a retenção e o sucesso acadêmico dos alunos e, consequentemente, melhores oportunidades de emprego e desenvolvimento econômico e social do país.
#
# Os benefícios deste projeto podem abranger desde a melhoria na qualidade da educação até o aumento das taxas de conclusão dos cursos superiores. O potencial de aplicabilidade das soluções propostas é significativo, pois pode contribuir para a formulação de políticas públicas educacionais mais eficientes e direcionadas ou até mesmo medidas mais individualizadas aplicadas diretamente pelas Instituições de ensino, sejam públicas ou privadas.
#
# O objetivo deste projeto é desenvolver um modelo de séries temporais capaz de analisar a taxa de conclusão dos alunos no ensino superior e identificar os fatores que mais influenciam a evasão acadêmica. Além disso, busca-se prever a probabilidade de alunos com determinadas características não concluírem o curso, permitindo a criação de estratégias de intervenção mais eficazes.
#
# Como objetivos específicos, pretende-se analisar o comportamento dos alunos ao longo dos anos, verificando os percentuais de conclusão e não conclusão, identificar as causas da evasão e utilizar dados históricos do INEP¹ para construir o modelo preditivo. O estudo visa contribuir para a formulação de políticas públicas educacionais mais eficientes e estratégias direcionadas para as Instituições de Ensino, sejam públicas ou privadas, visando reduzir a evasão e melhorar as taxas de conclusão no ensino superior.
# ¹https://www.gov.br/inep/pt-br/acesso-a-informacao/dados-abertos/microdados/censo-da-educacao-superior

# %% [markdown]
# # **Referencial Teórico**
#
# Para a composição do referencial teórico deste estudo, foi realizada uma busca por produções científicas relacionadas à temática da evasão no ensino superior. Contudo, verificou-se a escassez de pesquisas que abordem essa problemática por meio da modelagem com séries temporais, o que justificou a seleção de estudos que, embora não combinem todos os elementos abordados nesta pesquisa, oferecem importantes contribuições metodológicas. Dentre os trabalhos identificados, destaca-se aquele desenvolvido no Instituto Federal da Paraíba (IFPB), no qual a evasão foi investigada a partir de dados institucionais e aplicada a modelos de classificação supervisionada, como regressão logística, árvores de decisão e redes neurais. Os resultados apontaram que a regressão logística apresentou maior acurácia (81,24%), indicando que variáveis como tipo de curso, sexo, raça, renda familiar e turno das aulas influenciam significativamente na taxa de conclusão dos estudantes.(OLIVEIRA, 2023)
#
# Adicionalmente, foram considerados dois estudos que utilizaram modelos de séries temporais aplicados a diferentes contextos. O primeiro trata da inadimplência de consumidores no banco de dados do Serasa, sendo modelada por meio de técnicas estatísticas como o ARIMA, com destaque para a análise de padrões históricos segundo características demográficas. O segundo estudo empregou redes neurais artificiais na modelagem não linear de índices pluviométricos com o intuito de prever inundações no Pantanal. Ambos demonstraram a eficácia de técnicas de séries temporais na identificação de padrões complexos e na previsão de eventos futuros. Assim, apesar de não se referirem diretamente à evasão no ensino superior, esses trabalhos fornecem embasamento teórico e metodológico relevante para a aplicação de séries temporais no presente estudo.(BARBOSA; GERMANO, 2023) (KIDA; RIBEIRO, 2016)

# %% [markdown]
# # **Diagrama de Solução**
#
# **Coleta de Dados**
#
# A coleta de dados para este estudo foi realizada por meio do Instituto Nacional de Estudos e Pesquisas Educacionais Anísio Teixeira (INEP), que disponibiliza microdados sobre o ensino superior no Brasil. Os dados incluem informações detalhadas sobre instituições de ensino, cursos e alunos, abrangendo um período histórico significativo de 1995 a 2023. A seleção do período de análise será definida com base na disponibilidade e qualidade dos dados, bem como na relevância para a modelagem preditiva. Além disso, foram considerados fatores socioeconômicos e acadêmicos, como faixa etária, sexo, tipo de instituição (pública ou privada), modalidade de ensino (presencial ou a distância) e indicadores de permanência estudantil.
#
#
# **Processamento dos Dados**
#
# O processamento dos dados é realizado em etapas que incluem limpeza, transformação e preparação para a modelagem preditiva. Inicialmente, valores ausentes e inconsistências são tratados para garantir a integridade das informações. Em seguida, os dados categóricos são codificados para uso nos modelos, e as variáveis numéricas serão normalizadas quando necessário. Também pode ser feita a agregação temporal dos dados, permitindo a análise das tendências ao longo dos anos. Além disso, técnicas de feature engineering podem ser aplicadas para criar novas variáveis que possam contribuir para a explicação da evasão, como taxas de retenção por curso e índices de desempenho acadêmico.

# %% [markdown]
# # **EDA e Pré-processamento dos dados**
#
# A análise exploratória de dados (AED) constitui uma etapa fundamental no processo de investigação científica, pois permite compreender a estrutura dos dados, identificar padrões, detectar anomalias e formular hipóteses iniciais. Nesta seção, são apresentados os principais resultados da AED aplicada ao conjunto de dados sobre o ensino superior brasileiro, com foco nos indicadores de ingressantes, concluintes e taxa de conclusão ao longo do período analisado.
#
# ![image.png](data:image/png;base64,...)
#
# O primeiro gráfico mostra que o número de ingressantes cresceu ao longo do período analisado, com oscilações em alguns anos, mas apresentando uma forte tendência de alta após 2016. O aumento mais expressivo ocorreu entre 2020 e 2022. Em contrapartida, o número de concluintes teve um crescimento mais modesto e relativamente estável, sem variações tão acentuadas quanto o número de ingressantes. Essa discrepância sugere que, apesar de mais pessoas ingressarem no ensino superior, a quantidade de formandos não cresceu no mesmo ritmo.
#
# ![image.png](data:image/png;base64,...)
#
# O segundo gráfico reflete essa diferença ao exibir a queda contínua da taxa de conclusão ao longo dos anos. Em 2010, a taxa estava próxima de 45%, mas apresentou uma forte tendência de queda, chegando a valores abaixo de 30% em 2022. Isso indica que, proporcionalmente, menos alunos que ingressam estão conseguindo concluir seus cursos. Esse fenômeno pode estar relacionado a diversos fatores, como evasão acadêmica, dificuldades financeiras, qualidade do ensino ou mudanças estruturais nas universidades.

# %% [markdown]
# Abaixo, foi reproduzido o código utilizado para a fase de analise e exploração dos dados:

# %%
import os
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

import sqlite3

# %%
# Para ter acesso aos arquivos do Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Lista de diretórios (dependendo do local onde a base foi salva no Google Drive)
paths = [
    '/content/drive/MyDrive/Estudos/Mackenzie/projeto-aplicado-iv/share-mackenzie',
    '/content/drive/MyDrive/share/share-mackenzie'
]

# Itera nos diretórios e checa a existência
for path in paths:
    if os.path.exists(path):
        os.chdir(path)
        print(f"Usando o diretório: {path}")
        break
else:
    print("Nenhum dos diretórios são validos.")
# Out:
# Usando o diretório: /content/drive/MyDrive/share/share-mackenzie

# %%
conn = sqlite3.connect("inep.db")
cursor = conn.cursor()

# %%
cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")
tables = cursor.fetchall()

for table in tables:
    print(f"- {table[0]}")
# Out:
# - regions
# - states
# - municipalities
# - institutions
# - courses
# - cine_rotulos
# - cine_areas_gerais
# - cine_areas_especificas
# - cine_areas_detalhadas
# - microdados

# %%
df = pd.read_sql("SELECT * FROM microdados LIMIT 100", con=conn)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Columns: 107 entries, NU_ANO_CENSO to QT_CONC_MOB_ACADEMICA
# dtypes: int64(107)
# memory usage: 83.7 KB

# %%
df.columns[10:50]
# Out:
# Index(['QT_ING_NOTURNO', 'QT_ING_VG_NOVA', 'QT_ING_VESTIBULAR', 'QT_ING_ENEM',
#        'QT_ING_AVALIACAO_SERIADA', 'QT_ING_SELECAO_SIMPLIFICA', 'QT_ING_EGR',
#        'QT_ING_OUTRO_TIPO_SELECAO', 'QT_ING_PROC_SELETIVO',
#        'QT_ING_VG_REMANESC', 'QT_ING_VG_PROG_ESPECIAL', 'QT_ING_OUTRA_FORMA',
#        'QT_ING_0_17', 'QT_ING_18_24', 'QT_ING_25_29', 'QT_ING_30_34',
#        'QT_ING_35_39', 'QT_ING_40_49', 'QT_ING_50_59', 'QT_ING_60_MAIS',
#        'QT_ING_BRANCA', 'QT_ING_PRETA', 'QT_ING_PARDA', 'QT_ING_AMARELA',
#        'QT_ING_INDIGENA', 'QT_ING_CORND', 'QT_CONC', 'QT_CONC_FEM',
#        'QT_CONC_MASC', 'QT_CONC_DIURNO', 'QT_CONC_NOTURNO', 'QT_CONC_0_17',
#        'QT_CONC_18_24', 'QT_CONC_25_29', 'QT_CONC_30_34', 'QT_CONC_35_39',
#        'QT_CONC_40_49', 'QT_CONC_50_59', 'QT_CONC_60_MAIS', 'QT_CONC_BRANCA'],
#       dtype='object')

# %%
df = pd.read_sql(
    """
    SELECT
        NU_ANO_CENSO
        , COUNT(DISTINCT CO_MUNICIPIO) AS qtMunicipios
        , COUNT(DISTINCT CO_CURSO) AS qtCursos
        , COUNT(DISTINCT CO_IES) AS qtInstituicoes
        , SUM(QT_ING) AS qtIngressantes
        , SUM(QT_CONC) AS qtConcluintes
    FROM microdados
    GROUP BY NU_ANO_CENSO
    """, con=conn
    )

# %%
df
# Out:
#     NU_ANO_CENSO  qtMunicipios  qtCursos  qtInstituicoes  qtIngressantes  \
# 0           2010          1866     29479            2377         2133117
# 1           2011          1739     30309            2365         2223172
# 2           2012          1678     31637            2415         2507695
# 3           2014          1498     32557            2365         2725223
# 4           2015          1438     33045            2360         2477136
# 5           2016          1378     33727            2402         2373854
# 6           2017          1701     35224            2447         3003702
# 7           2018          2074     37659            2537         3162413
# 8           2019          2280     39894            2608         3251845
# 9           2021          3042     43053            2574         3926466
# 10          2022          3309     45243            2595         4755158
# 11          2023          3493     45890            2580         4955207
#
#     qtConcluintes
# ...

# %%
df_melted = df.melt(id_vars=["NU_ANO_CENSO"],
                     value_vars=["qtIngressantes", "qtConcluintes"],
                     var_name="Categoria", value_name="Quantidade")

# Set Seaborn theme
sns.set_style("whitegrid")

# Create the plot
plt.figure(figsize=(10, 5))
sns.lineplot(data=df_melted, x="NU_ANO_CENSO", y="Quantidade", hue="Categoria", marker="o")

# Customize the plot
plt.xlabel("Ano do Censo")
plt.ylabel("Quantidade")
plt.title("Evolução de Ingressantes e Concluintes por Ano")
plt.legend(title="Categoria")

# Show the plot
plt.show()

# %%
df["Ratio"] = df["qtConcluintes"] / df["qtIngressantes"]

plt.figure(figsize=(10, 5))
sns.lineplot(data=df, x="NU_ANO_CENSO", y="Ratio", marker="o")
plt.xlabel("Ano do Censo")
plt.ylabel("Taxa de Conclusão")
plt.title("Evolução da Taxa de Conclusão (Concluintes / Ingressantes)")
plt.grid(True)
plt.show()

# %% [markdown]
# No gráfico acima podemos ver o efeito da COVID na taxa de concluintes, apesar de que ela já vinha diminuindo desde antes da COVID

# %%
df_melted = df.melt(id_vars=["NU_ANO_CENSO"],
                     value_vars=["qtMunicipios", "qtCursos", "qtInstituicoes"],
                     var_name="Categoria", value_name="Quantidade")

plt.figure(figsize=(10, 5))
sns.lineplot(data=df_melted, x="NU_ANO_CENSO", y="Quantidade", hue="Categoria", marker="o")
plt.xlabel("Ano do Censo")
plt.ylabel("Quantidade")
plt.title("Crescimento de Instituições, Cursos e Municípios")
plt.legend(title="Categoria")
plt.grid(True)
plt.show()

# %%
df["growthIngressantes"] = df["qtIngressantes"].pct_change() * 100
df["growthConcluintes"] = df["qtConcluintes"].pct_change() * 100

df_melted = df.melt(id_vars=["NU_ANO_CENSO"],
                     value_vars=["growthIngressantes", "growthConcluintes"],
                     var_name="Categoria", value_name="Crescimento (%)")

plt.figure(figsize=(10, 5))
sns.barplot(data=df_melted, x="NU_ANO_CENSO", y="Crescimento (%)", hue="Categoria")
plt.xlabel("Ano do Censo")
plt.ylabel("Crescimento (%)")
plt.title("Crescimento Anual de Ingressantes e Concluintes (%)")
plt.axhline(0, color='gray', linestyle='--')  # Add baseline at 0%
plt.legend(title="Categoria")
plt.grid(True)
plt.show()

# %% [markdown]
# # **Modelo base**
#
# Aplicação de, pelo menos, um primeiro modelo (modelo de aprendizado de máquina ou modelo estatístico) que deve ser refinado até a entrega final do projeto. Apresente o método aplicado e a análise dos resultados obtidos.

# %%
from statsmodels.tsa.arima.model import ARIMA
from sklearn.metrics import mean_squared_error

# %%
# Carregue os dados da série temporal
data = df

# Divida os dados em conjuntos de treinamento e teste
train_data = data[:-5]  # Use os últimos 5 pontos de dados para teste
test_data = data[-5:]

# %%
# Crie o modelo ARIMA (p, d, q)
model = ARIMA(train_data['Taxa_Conclusao'], order=(5, 1, 0))

# %%
# Plote as previsões e os dados reais
plt.plot(test_data['Taxa_Conclusao'], label='Real')
plt.plot(predictions, label='Previsões')
plt.legend()
plt.show()

# %% [markdown]
# # **Cronograma**
#
# A seguir apresentamos o cronograma do projeto, considerando as principais entregas.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **Referências**
#
# Análise de dados aplicada à evasão escolar : um estudo de caso do IFPB / Isleimar de Souza Oliveira. – 2023. 136 f. : il.
#
# BARBOSA, J. R.; GERMANO, R. MODELAGEM MATEMÁTICA DA INADIMPLÊNCIA NO SERASA: UMA ANÁLISE ESTATÍSTICA E DE SÉRIE TEMPORAL. Educação, Ensino e Geração de Renda: estratégias e propostas em economia solidária, p. 79–91, 2023.
#
#
# ‌KIDA, Gerson; RIBEIRO, Eduardo M. Redes Neurais Artificiais em Série Temporal Não-Linear de Índice Pluviométrico Para Determinação de Inundação em Bacias do Pantanal. ResearchGate, 2016. Disponível em: https://www.researchgate.net/profile/Gerson-Kida/publication/308854161_Redes_Neurais_Artificiais_em_Serie_Temporal_Nao-Linear_de_Indice_Pluviometrico_Para_Determinacao_de_Inundacao_em_Bacias_do_Pantanal/links/57f3ae2608ae886b897dbd55/Redes-Neurais-Artificiais-em-Serie-Temporal-Nao-Linear-de-Indice-Pluviometrico-Para-Determinacao-de-Inundacao-em-Bacias-do-Pantanal.pdf. Acesso em: 26-03-2025.

# %%
#@title **Avaliação**
EDA_e_preprocessamento = 10 #@param {type:"slider", min:0, max:10, step:1}

Modelo_base = 10 #@param {type:"slider", min:0, max:10, step:1}

Revisao = 10 #@param {type:"slider", min:0, max:10, step:1}

Apresentacao_geral = 10 #@param {type:"slider", min:0, max:10, step:1}

# %%
#@title **Nota Final**
nota = 0.4*EDA_e_preprocessamento + 0.2*Modelo_base + 0.2*Revisao + 0.2*Apresentacao_geral

print(f'Nota final do trabalho {nota :.1f}')

import numpy as np
import pandas as pd

alunos = pd.DataFrame()

lista_nome = []

for i in range(1,6):
  exec("if Aluno" + str(i) + " !='None':  lista = Aluno" + str(i) + ".split(','); lista_nome.append(lista[0]);")

alunos['nome'] = lista_nome
alunos['nota'] = np.round(nota,1)
print()
display(alunos)
# Out:
# Nota final do trabalho 10.0
#       nome  nota
# 0  Aluno 1  10.0
# 1  Aluno 2  10.0
# 2  Aluno 3  10.0
# 3  Aluno 4  10.0
# 4  Aluno 5  10.0
